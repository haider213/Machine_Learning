# %% [markdown]
# We are going to write the very basics of neural networks using tensorflow and specifically keras

# %%
import keras.layers
import pandas as pd
import numpy as np
import keras
from keras import Sequential
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Let us assume we have a data set that looks like this

# %%
x=np.arange(-1,5)

# %%
y=2*x-1

# %%
y
# Out:
# array([-3, -1,  1,  3,  5,  7])

# %%
plt.plot(x,y)

# %% [markdown]
# We already know the relationship between x and y but let's suppose we did not, in the ML paradigm we give both the input and the output to the ML algorithm to figure out the relationship

# %% [markdown]
# Let us now define a linear model using Sequential from keras

# %%
model=Sequential(keras.layers.Dense(units=1, input_shape=[1]))

# %% [markdown]
# Another way of defining the same thing is
# a linear activation is characterised by the following $a=w*x+b$
# In keras you use Dense to define a layer of connected neurons

# %%
a=keras.layers.Dense(units=1,input_shape=[1],activation='linear')

# %%
a.build(input_shape=[1])

# %%
a

# %% [markdown]
# SGD is single gradient descent with momentum explained here: https://keras.io/api/optimizers/sgd/

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit?

# %%
model.fit(x,y,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 537ms/step - loss: 9.0151
# Epoch 2/1000
# 1/1 [==============================] - 0s 0s/step - loss: 7.2970
# Epoch 3/1000
# 1/1 [==============================] - 0s 0s/step - loss: 5.9411
# Epoch 4/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.8703
# Epoch 5/1000
# 1/1 [==============================] - 0s 0s/step - loss: 4.0237
# Epoch 6/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 3.3538
# Epoch 7/1000
# 1/1 [==============================] - 0s 0s/step - loss: 2.8228
# Epoch 8/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 2.4013
# Epoch 9/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0660
# Epoch 10/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7985
# Epoch 11/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5846
# Epoch 12/1000
# 1/1 [==============================] - 0s 0s/step - loss: 1.4127
# ...

# %%
model.get_weights()
# Out:
# [array([[1.9999859]], dtype=float32), array([-0.99995714], dtype=float32)]

# %%
print(model.predict([10]))
# Out:
# 1/1 [==============================] - 0s 115ms/step
# [[18.9999]]
